# %%
import imageio
import imgaug as ia
import imgaug.augmenters as iaa
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib
# %matplotlib inline

# %%
image = imageio.imread("dal.jpg")
ia.imshow(image)

# %%
#rotating image
rotate=iaa.Affine(rotate=(-50, 30))
rotated_image=rotate.augment_image(image)
ia.imshow(rotated_image)

# %%
# Adding noise to image
gaussian_noise=iaa.AdditiveGaussianNoise(10,20)
noise_image=gaussian_noise.augment_image(image)
ia.imshow(noise_image)

# %%
#croping a image
crop = iaa.Crop(percent=(0, 0.3)) # crop image
corp_image=crop.augment_image(image)
ia.imshow(corp_image)

# %%
#shearing a image
shear = iaa.Affine(shear=(0,40))
shear_image=shear.augment_image(image)
ia.imshow(shear_image)

# %%
#flipping image horizontally
flip_hr=iaa.Fliplr(p=1.0)
flip_hr_image= flip_hr.augment_image(image)
ia.imshow(flip_hr_image)

# %%
#flipping vertically
flip_vr=iaa.Flipud(p=1.0)
flip_vr_image= flip_vr.augment_image(image)
ia.imshow(flip_vr_image)

# %%
#changing brightness
image = imageio.imread("dal.jpg")
contrast=iaa.GammaContrast(gamma=2.0)
contrast_image =contrast.augment_image(image)
ia.imshow(contrast_image)

# %%
#image scaling
image = imageio.imread("dal.jpg")
scale_im=iaa.Affine(scale={"x": (1.5, 1.0), "y": (1.5, 1.0)})
scale_image =scale_im.augment_image(image)
ia.imshow(scale_image)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
import glob
import os
os.listdir('images\dum_aloo')
# Out:
# ['0703f0b113.jpg',
#  '0a548eb444.jpg',
#  '0ba82d276f.jpg',
#  '0d8d759a94.jpg',
#  '16f70adf27.jpg',
#  '171f99c720.jpg',
#  '18664ac711.jpg',
#  '1a2272952c.jpg',
#  '1ae0b65f4c.jpg',
#  '1c599e2731.jpg',
#  '1cb8a48649.jpg',
#  '1ecb0633d0.jpg',
#  '21747ca2e6.jpg',
#  '226977e074.jpg',
#  '2537799ddb.jpg',
#  '269be0924b.jpg',
#  '2e7b6fb8d7.jpg',
#  '31d529b006.jpg',
#  '33256cdbcf.jpg',
#  '343989f757.jpg',
#  '35ec0bd783.jpg',
#  '3aa61f6d85.jpg',
#  '3ca98e85a5.jpg',
#  '3ea9079938.jpg',
#  '3fcf86cd3e.jpg',
#  '42629baf93.jpg',
#  '45df4adca6.jpg',
#  '4bf7b387cf.jpg',
#  '4c0e6406cd.jpg',
#  '4e34baf8f1.jpg',
#  '4ef6bb7776.jpg',
#  '51b5315477.jpg',
#  '54ce5983ec.jpg',
#  '55187b27ae.jpg',
#  '599aca9b7f.jpg',
#  '5a9689f6e9.jpg',
#  '5bf364f531.jpg',
#  '5cb9d432ce.jpg',
#  '5e4e408c78.jpg',
#  '5e6266ac6a.jpg',
#  '628063351d.jpg',
#  '63a21b8eb3.jpg',
#  '63b7356b67.jpg',
#  '63ea1d81a7.jpg',
#  '6598693223.jpg',
#  '666dda68ef.jpg',
#  '6aac53c81b.jpg',
# ...

# %%
for folder in os.listdir('images'):
    img_dir =  os.path.join('images',folder)
    for img in os.listdir(img_dir):
       
        image = load_img(os.path.join(r'C:\Users\thaku\Downloads',img_dir,img))
        
        image = img_to_array(image)
        
        image = np.expand_dims(image, axis=0)


        aug = ImageDataGenerator(
                                rotation_range=45,
                                zoom_range=0.20,
                                fill_mode="nearest")
        total = 0

        print("[INFO] generating images...")
        imageGen = aug.flow(image, batch_size=1, save_to_dir=os.path.join(r'C:\Users\thaku\Downloads',img_dir),
                            save_prefix="image", save_format="jpg")
        
        for image in imageGen:
            total+=1
    
            if total==2:
                break
# Out:
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# [INFO] generating images...
# ...

# %%
image = load_img(r'C:\Users\thaku\Downloads\images\ghewar\1.jpg')
image = img_to_array(image)
image = np.expand_dims(image, axis=0)


aug = ImageDataGenerator(
    rotation_range=90,
    fill_mode="nearest")
total = 0

print("[INFO] generating images...")
imageGen = aug.flow(image, batch_size=1, save_to_dir=r'C:\Users\thaku\Downloads\aug_data',
    save_prefix="image", save_format="jpg")
# Out:
# [INFO] generating images...

# %%
import matplotlib.pyplot as plt

# %%
for image in imageGen:
    total+=1
    
    if total==2:
        break
